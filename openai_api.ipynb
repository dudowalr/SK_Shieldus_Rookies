# %% [markdown]
# OpenAI API

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\sk_shieldus_rookies\.venv\lib\site-packages (1.2.2)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#KEY
from dotenv import load_dotenv
import os

load_dotenv()

# 사용할 KEY 가져오기
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
# OpenAI 연결
from openai import OpenAI

# %%
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# 응답 생성 : Responses
response = client.responses.create(
    model='gpt-5.4',
    input='스타워즈 시리즈의 다스베이터의 역할에 대해 한줄로 설명해줘'
)

# %%
# 응답의 결과 확인
print(response.output_text)
# Out:
# 다스 베이더는 은하 제국의 공포를 상징하는 시스 군주이자, 결국 루크의 아버지로서 비극적 구원의 중심에 서는 인물입니다.

# %%
response = client.responses.create(
    model='gpt-5.4',
    instructions='당신은 영화평론가야',
    input='스타워즈 시리즈의 다스베이터의 역할에 대해 한줄로 설명해줘'
)
print(response.output_text)
# Out:
# 다스 베이더는 스타워즈에서 타락한 영웅이자 제국의 공포를 상징하면서, 결국 구원의 가능성까지 보여주는 비극적 핵심 인물이다.

# %%
# 응답의 결과 확인
print(response.output_text)
# Out:
# 다스 베이더는 스타워즈에서 타락한 영웅이자 제국의 공포를 상징하면서, 결국 구원의 가능성까지 보여주는 비극적 핵심 인물이다.

# %%
response = client.responses.create(
    model='gpt-5.4',
    input=[
        {
        'role':'developer',
        'content':'음식에 대한 이야기 하는것을 좋아해'
    },
    {
        'role':'user',
        'content':'오늘 점심은 무엇을 먹을까?'
    }
    ]

)
print(response.output_text)
# Out:
# 좋아요, 이런 고민 정말 즐겁죠.
# 오늘 점심은 **지금 기분**에 따라 고르면 실패가 적어요. 추천해볼게요:
#
# ### 1. 든든하게 먹고 싶다면
# - **제육볶음 정식**
# - **국밥**
# - **돈까스**
# → 배부르고 만족감이 커요.
#
# ### 2. 깔끔하고 가볍게 먹고 싶다면
# - **비빔밥**
# - **쌀국수**
# - **샌드위치 + 수프**
# → 오후에 덜 졸릴 가능성이 높아요.
#
# ### 3. 따뜻하고 편한 음식이 땡긴다면
# - **순두부찌개**
# - **칼국수**
# - **우동**
# → 속 편하고 무난해요.
#
# ### 4. 오늘 좀 기분전환하고 싶다면
# - **마라탕**
# - **초밥**
# - **타코/브리또**
# → 평소보다 조금 특별한 느낌이 나요.
#
# ### 빠르게 하나 골라드리면
# 오늘 무난하게 성공하려면: **순두부찌개 or 제육볶음**
# 깔끔하게 가려면: **쌀국수**
# 확실한 만족감이면: **돈까스**
#
# 원하면 제가
# **“한식 / 면 / 가벼운 것 / 매운 것”** 중 취향에 맞춰서 **딱 3개로 좁혀드릴게요.**

# %% [markdown]
# 유치원 선생님 질문을 받아서 답변하는 형식

# %%
user_input = input("궁금한걸 물어보렴")
print('질문: ', user_input)
# Out:
# 질문:  집에 가고싶을땐

# %%
response = client.responses.create(
    model='gpt-5.4',
    input=[
        {
        'role':'developer',
        'content':'유치원 선생님이고, 정신련령 2~7세 유치원 아이들을 다룬다고 가정해서 답변.'
    },
    {
        'role':'user',
        'content':user_input
    }
    ]
    

)
print(response.output_text)
# Out:
# 집에 가고 싶을 땐 이렇게 말하면 돼요 😊
#
# - **“선생님, 집에 가고 싶어요.”**
# - **“엄마(아빠) 보고 싶어요.”**
# - **“조금 쉬고 싶어요.”**
# - **“선생님, 속상해요.”**
#
# 선생님은 이렇게 도와줄 거예요:
# - 꼭 안아주기
# - 물 마시기
# - 잠깐 쉬기
# - 엄마 아빠 생각하며 기다리기
#
# 조금만 놀고 나면 집에 갈 시간이 와요 💛
# 필요하면 같이 말해볼까요?
#
# **“선생님, 집에 가고 싶어요.”**

# %%
response = client.chat.completions.create(
    model='gpt-5.4',
    messages = [
        {
            'role' : 'user',
            'content' : '미니언즈 시리즈에 대해 설명해줘'
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# **미니언즈 시리즈**는 일루미네이션(Illumination)이 만든 애니메이션 프랜차이즈로, 원래 **《슈퍼배드(Despicable Me)》 시리즈**에서 등장한 노란색 조연 캐릭터들인 **미니언**이 큰 인기를 얻으면서 독립 시리즈로 확장된 작품입니다.
#
# ## 1. 기본 개요
# - **제작사**: 일루미네이션
# - **배급사**: 유니버설 픽처스
# - **장르**: 코미디, 가족, 애니메이션, 어드벤처
# - **특징**:
#   - 노란색 몸체
#   - 고글 착용
#   - 독특한 언어 사용(여러 언어가 섞인 듯한 말투)
#   - 단순하지만 엉뚱하고 귀여운 행동
#
# ## 2. 세계관 핵심 설정
# 미니언들은 아주 오래전부터 존재해온 생명체로, 본능적으로 **가장 강력하고 사악한 주인**을 섬기고 싶어 합니다.
# 하지만 늘 사고를 쳐서 주인을 곤란하게 만들거나 잃어버리곤 합니다. 이 설정이 시리즈의 주요 코미디 요소입니다.
#
# ## 3. 주요 작품 순서
# ### 슈퍼배드 본편
# 1. **《슈퍼배드》 (2010)**
#    - 악당 **그루( Gru )**와 세 소녀, 그리고 미니언들이 처음 본격 등장
#    - 미니언은 조연이지만 엄청난 인기를 얻음
#
# 2. **《슈퍼배드 2》 (2013)**
#    - 그루가 본격적으로 가족적인 면모를 보이며 활약
#    - 미니언들의 비중과 개그가 더 커짐
#
# 3. **《슈퍼배드 3》 (2017)**
#    - 그루의 쌍둥이 형제 **드루** 등장
#    - 미니언들의 독자적인 활약도 많아짐
#
# 4. **《슈퍼배드 4》 (2024)**
#    - 그루 가족의 새로운 이야기가 이어짐
#    - 미니언들의 활약 역시 계속됨
#
# ### 미니언즈 스핀오프
# 1. **《미니언즈》 (2015)**
#    - 미니언들이 그루를 만나기 전의 이야기
#    - 케빈, 스튜어트, 밥이 새로운 주인을 찾기 위해 모험
#    - 악당 **스칼렛 오버킬**이 주요 인물
#
# 2. **《미니언즈 2》 / 《미니언즈: 라이즈 오브 그루》 (2022)**
#    - 어린 시절의 그루가 등장
#    - 미니언들과 그루가 어떻게 함께하게 되었는지 다룸
#    - 그루의 어린 악당 시절을 볼 수 있음
#
# ## 4. 대표 미니언 캐릭터
# - **케빈**
#   - 비교적 똑똑하고 리더 역할
#   - 키가 큰 편
#
# - **스튜어트**
#   - 한쪽 눈 고글
#   - 장난기 많고 자유분방함
#   - 기타를 좋아하는 모습이 자주 나옴
#
# - **밥**
#   - 작고 귀여운 이미지
#   - 순수하고 사랑스러운 성격
#   - 곰인형을 좋아함
#
# 이 셋이 특히 스핀오프에서 중심 캐릭터로 활약합니다.
#
# ## 5. 미니언즈 시리즈의 인기 이유
# - **말이 많지 않아도 통하는 슬랩스틱 코미디**
# - **어른과 아이 모두 즐길 수 있는 단순하고 직관적인 유머**
# - **귀엽고 개성 강한 캐릭터 디자인**
# - **빠른 전개와 시각적인 재미**
# - **굿즈, 밈, SNS에서 강한 화제성**
#
# ## 6. 시리즈 분위기
# 미니언즈 시리즈는 대체로
# - 밝고 유쾌하고
# - 빠른 템포의 개그가 많고
# - 진지한 서사보다는 캐릭터 매력과 웃음에 집중합니다.
#
# 그래서 깊은 드라마보다는 **가볍게 즐기기 좋은 가족용 애니메이션**으로 평가받습니다.
#
# ## 7. 한줄 요약
# **미니언즈 시리즈는 《슈퍼배드》에서 탄생한 노란 캐릭터 미니언들을 중심으로, 엉뚱한 모험과 코미디를 보여주는 인기 애니메이션 시리즈**입니다.
#
# 원하시면 제가 이어서
# - **영화별 줄거리 요약**
# - **등장인물 총정리**
# - **보는 순서 추천**
# - **슈퍼배드 시리즈와의 차이점**
# 중 하나로 더 자세히 설명해드릴게요.

# %% [markdown]
# function calling

# %%
import requests
def get_weather(latitude, longitude):
    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
    data = response.json()
    return data['current']['temperature_2m']

# %%
#함수의 설정 정의
# 여러개의 함수를 정의할 수 있다
tools = [
    {
    "type": "function",
    "name": "get_weather",
    "description": "Get current temperature for provided coordinates in celsius.",
    "parameters": {
        "type": "object",
        "properties": {
            "latitude": {"type": "number"},
            "longitude": {"type": "number"}
        },
        "required": ["latitude", "longitude"],
        "additionalProperties": False
    },
    "strict": True
}
]

# %%
input_messages = [
    {
        'role' : 'user',
        'content' : '오늘 파리 날씨는 어때? '
    }
]

response = client.responses.create(
    model = 'gpt-5.4',
    input=input_messages,
    tools=tools,
)

# %%
response.output[0]
dict(response.output[0])
# Out:
# {'arguments': '{"latitude":48.8566,"longitude":2.3522}',
#  'call_id': 'call_Bl8vncCsQk3DfOesZBr25PHN',
#  'name': 'get_weather',
#  'type': 'function_call',
#  'id': 'fc_05c18b294b747b4e0069bd04e446f0819695ff01940fa31810',
#  'namespace': None,
#  'status': 'completed'}

# %%
import json

# %%
response.output
# Out:
# [ResponseFunctionToolCall(arguments='{"latitude":48.8566,"longitude":2.3522}', call_id='call_Bl8vncCsQk3DfOesZBr25PHN', name='get_weather', type='function_call', id='fc_05c18b294b747b4e0069bd04e446f0819695ff01940fa31810', namespace=None, status='completed')]

# %%
tool_call = response.output[0]
# 모델이 함수에 사용할 파라미터 데이터를 추출
args = json.loads(tool_call.arguments)
# 함수 호출
result = get_weather(args['latitude'], args['longitude'])

print('함수 호출 결과: ', result)
# Out:
# 함수 호출 결과:  8.2

# %%
#메세지 병합
input_messages.append(tool_call)

#함수 실행 결과 추가
input_messages.append({
    'type' : 'function_call_output',
    'call_id' : tool_call.call_id,
    'output' : str(result)
})

print(input_messages)
# Out:
# [{'role': 'user', 'content': '오늘 파리 날씨는 어때? '}, ResponseFunctionToolCall(arguments='{"latitude":48.8566,"longitude":2.3522}', call_id='call_Bl8vncCsQk3DfOesZBr25PHN', name='get_weather', type='function_call', id='fc_05c18b294b747b4e0069bd04e446f0819695ff01940fa31810', namespace=None, status='completed'), {'type': 'function_call_output', 'call_id': 'call_Bl8vncCsQk3DfOesZBr25PHN', 'output': '8.2'}]

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\sk_shieldus_rookies\.venv\lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in c:\sk_shieldus_rookies\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\sk_shieldus_rookies\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in .\.venv\Lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\.venv\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\.venv\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\.venv\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in .\.venv\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\.venv\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in .\.venv\Lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in .\.venv\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in .\.venv\Lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\.venv\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\.venv\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in .\.venv\Lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in .\.venv\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in .\.venv\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\.venv\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in .\.venv\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in .\.venv\Lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\.venv\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\.venv\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\.venv\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\.venv\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
